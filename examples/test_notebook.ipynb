# %% [markdown]
# # Multi-Task Learning with PyTorch: Complete Tutorial
#
# This notebook demonstrates multi-task learning on MNIST with 4 different tasks.

# %%
import torch
print("PyTorch version:", torch.__version__)
